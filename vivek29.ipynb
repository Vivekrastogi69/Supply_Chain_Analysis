# %% [markdown]
# # Day 29

# %% [markdown]
# # Supply Chain Analysis Project

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
pio.templates.default = "plotly_white"

# %%
data = pd.read_csv("supply_chain_data.csv")
data.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
data.describe()
# Out:
#             Price  Availability  Number of products sold  Revenue generated  \
# count  100.000000    100.000000               100.000000         100.000000
# mean    49.462461     48.400000               460.990000        5776.048187
# std     31.168193     30.743317               303.780074        2732.841744
# min      1.699976      1.000000                 8.000000        1061.618523
# 25%     19.597823     22.750000               184.250000        2812.847151
# 50%     51.239831     43.500000               392.500000        6006.352023
# 75%     77.198228     75.000000               704.250000        8253.976921
# max     99.171329    100.000000               996.000000        9866.465458
#
#        Stock levels  Lead times  Order quantities  Shipping times  \
# count    100.000000  100.000000        100.000000      100.000000
# mean      47.770000   15.960000         49.220000        5.750000
# std       31.369372    8.785801         26.784429        2.724283
# ...

# %% [markdown]
# # relationship between the price of products and the revenue generated by them

# %%
fig = px.scatter(data, x='Price',
                 y='Revenue generated',
                 color='Product type',
                 hover_data=['Number of products sold'],
                 trendline="ols")
fig.show()

# %% [markdown]
# thus, the company derives more revenue from skincare products, and the higher the price of skincare products , the more revenue the generate

# %% [markdown]
# # Now let's have a look at the scale by product type:

# %%
sales_data = data.groupby('Product type')['Number of products sold'].sum().reset_index()
sales_data
# Out:
#   Product type  Number of products sold
# 0    cosmetics                    11757
# 1     haircare                    13611
# 2     skincare                    20731

# %%
sales_data = data.groupby('Product type')['Number of products sold'].sum().reset_index()

pie_chart = px.pie(sales_data, values='Number of products sold',
                   names='Product type',
                   title='Sales by Product Type',
                   hover_data=['Number of products sold'],
                   hole=0.5,
                   color_discrete_sequence=px.colors.qualitative.Pastel)

pie_chart.update_traces(textposition='inside', textinfo='percent+label')
pie_chart.show()

# %% [markdown]
# so 45% of the business comes from skincare products, 29.5% from haircare, and 25.5% from cosmetics
#
# # Total revenue generated from shipping carriers

# %%
total_revenue = data.groupby('Shipping carriers')['Revenue generated'].sum().reset_index()
total_revenue
# Out:
#   Shipping carriers  Revenue generated
# 0         Carrier A      142629.994607
# 1         Carrier B      250094.646988
# 2         Carrier C      184880.177143

# %%
total_revenue = data.groupby('Shipping carriers')['Revenue generated'].sum().reset_index()
fig = go.Figure()
fig.add_trace(go.Bar(x=total_revenue['Shipping carriers'],
                     y=total_revenue['Revenue generated']))
fig.update_layout(title='Total Revenue by Shipping Carrier',
                  xaxis_title = 'Shipping Carrier',
                  yaxis_title='Revenue Generated')
fig.show()

# %% [markdown]
# So the company is using three cariers for transpotation, and carier B help the company in generating more revenue
#
# there's a column in the dataset as SKUs. you must have heared it for the very firs time. so, SKU stands for Stock Keeping Unit. they're like
# special codes that helps company keeps track of all the differeny things they have for sale. imagin you have a large toy store with lot's of toys.
# Each toy is diffrent and has its name and price. but when you want to how many you have left you nedd a way to identify them. so you give each toy a
# unique code, like a secret number only the store knows. this secret number is called SKU.
#
#
# # Let's analyze the revenue genrated by each SKU:

# %%
revenue_chart = px.line(data, x='SKU',
                        y='Revenue generated',
                        title='Revenue Generated by SKU')
revenue_chart.show()

# %% [markdown]
# # Now let's have a look at the order quantity of each SKU:

# %%
order_quantity_chart = px.bar(data, x='SKU',
                              y='Order quantities',
                              title='Order Qunatity by SKU')
order_quantity_chart.show()

# %% [markdown]
# # Now let's analyze the shipping cost of carrer:

# %%
shipping_cost_chart = px.bar(data, x='Shipping carriers',
                             y='Shipping costs',
                             title='Shipping Cost by Carrier')
shipping_cost_chart.show()

# %% [markdown]
# # Cost distribution by transpotation mode:

# %%
transportation_chart = px.pie(data,
                              values='Costs',
                              names='Transportation modes',
                              title='Cost Distribution by Transportation Mode',  # Corrected here
                              hole=0.5,
                              color_discrete_sequence=px.colors.qualitative.Pastel)
transportation_chart.show()

# %% [markdown]
# # Amazing Defect Rate

# %%
defect_rates_by_product = data.groupby('Product type')['Defect rates'].mean().reset_index()
defect_rates_by_product
# Out:
#   Product type  Defect rates
# 0    cosmetics      1.919287
# 1     haircare      2.483150
# 2     skincare      2.334681

# %%
defect_rates_by_product = data.groupby('Product type')['Defect rates'].mean().reset_index()

fig = px.bar(defect_rates_by_product, x ='Product type' , y='Defect rates',
             title='Average Defect Rate by Product
